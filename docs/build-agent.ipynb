# %%
# !adk create --type=code koffi --model gemini-2.5-flash-native-audio-preview-09-2025 --api_key $GEMINI_API_KEY
# Out:
# Agent created in /home/levi/Desktop/ProjectPerso/KOFFI_Agent/koffi:
# - .env
# - __init__.py
# - agent.py
